# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Human_Activity_Recognition_Using_Smartphones_Data.csv')
df['Activity'] = df['Activity'].map(
    {
        'STANDING':0,
        'SITTING':1,
        'LAYING':2,
        'WALKING':3,
        'WALKING_DOWNSTAIRS':4,
        'WALKING_UPSTAIRS':5,
    }
)
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# 0         -0.923527         -0.934724    ...
# 1         -0.957686         -0.943068    ...
# 2         -0.977469         -0.938692    ...
# 3         -0.989302         -0.938692    ...
# 4         -0.990441         -0.942469    ...
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                        -0.298676                        -0.710304
# 1                        -0.595051                        -0.861499
# 2                        -0.390748                        -0.760104
# 3                        -0.117290                        -0.482845
# 4                        -0.351471                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0             -0.841247              0.179941             -0.058627         0
# 1             -0.844788              0.180289             -0.054317         0
# 2             -0.848933              0.180637             -0.049118         0
# 3             -0.848649              0.181935             -0.047663         0
# 4             -0.847865              0.185151             -0.043892         0
#
# [5 rows x 562 columns]

# %%
X = np.array(df.drop(['Activity'],1))
y = np.array(df['Activity'])
print(X.shape)
print(y.shape)
# Out:
# (10299, 561)
# (10299,)

# %%
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras import regularizers
# from keras.model_selection import train_test_split

labels = np_utils.to_categorical(y,6)
X = X.astype('float32')
y = y.astype('float32')



# X_train, x_test, Y_train, y_test = train_test_split(X,test_size = 0.3)

# %%
model = Sequential([
    Dense(units=64, input_dim = 561),
    Activation('relu'),
    
    Dense(units = 32),
    Activation('relu'),
    
    Dense(units = 32),
    Activation('relu'),

    Dense(units = 6),
    Activation('softmax'),
])

# %% [markdown]
# model.summary()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_150 (Dense)            (None, 64)                35968
# _________________________________________________________________
# activation_143 (Activation)  (None, 64)                0
# _________________________________________________________________
# dense_151 (Dense)            (None, 32)                2080
# _________________________________________________________________
# activation_144 (Activation)  (None, 32)                0
# _________________________________________________________________
# dense_152 (Dense)            (None, 32)                1056
# _________________________________________________________________
# activation_145 (Activation)  (None, 32)                0
# _________________________________________________________________
# dense_153 (Dense)            (None, 6)                 198
# _________________________________________________________________
# activation_146 (Activation)  (None, 6)                 0
# =================================================================
# Total params: 39,302
# Trainable params: 39,302
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.fit(X,labels,epochs=15, batch_size = 25)
# Out:
# Epoch 1/15
# 10299/10299 [==============================] - 3s 283us/step - loss: 0.3784 - acc: 0.8469
# Epoch 2/15
# 10299/10299 [==============================] - 2s 159us/step - loss: 0.1376 - acc: 0.9469
# Epoch 3/15
# 10299/10299 [==============================] - 2s 160us/step - loss: 0.1026 - acc: 0.9594
# Epoch 4/15
# 10299/10299 [==============================] - 2s 160us/step - loss: 0.0929 - acc: 0.9632
# Epoch 5/15
# 10299/10299 [==============================] - 2s 161us/step - loss: 0.0785 - acc: 0.9692
# Epoch 6/15
# 10299/10299 [==============================] - 2s 160us/step - loss: 0.0792 - acc: 0.9670
# Epoch 7/15
# 10299/10299 [==============================] - 2s 170us/step - loss: 0.0723 - acc: 0.9722
# Epoch 8/15
# 10299/10299 [==============================] - 2s 185us/step - loss: 0.0663 - acc: 0.9735
# Epoch 9/15
# 10299/10299 [==============================] - 2s 178us/step - loss: 0.0645 - acc: 0.9744
# Epoch 10/15
# 10299/10299 [==============================] - 2s 166us/step - loss: 0.0676 - acc: 0.9718
# Epoch 11/15
# 10299/10299 [==============================] - 2s 167us/step - loss: 0.0618 - acc: 0.9762
# Epoch 12/15
# 10299/10299 [==============================] - 2s 190us/step - loss: 0.0631 - acc: 0.9749
# Epoch 13/15
# 10299/10299 [==============================] - 2s 196us/step - loss: 0.0648 - acc: 0.9741
# Epoch 14/15
# 10299/10299 [==============================] - 2s 169us/step - loss: 0.0556 - acc: 0.9787
# Epoch 15/15
# 10299/10299 [==============================] - 2s 165us/step - loss: 0.0533 - acc: 0.9790
