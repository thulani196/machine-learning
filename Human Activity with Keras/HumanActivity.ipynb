# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Human_Activity_Recognition_Using_Smartphones_Data.csv')
df['Activity'] = df['Activity'].map(
    {
        'STANDING':0,
        'SITTING':1,
        'LAYING':2,
        'WALKING':3,
        'WALKING_DOWNSTAIRS':4,
        'WALKING_UPSTAIRS':5,
    }
)
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
X = np.array(df.drop(['Activity'],1))
y = np.array(df['Activity'])
print(X.shape)
print(y.shape)
# Out:
# (10299, 561)
# (10299,)

# %%
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras import regularizers
# from keras.model_selection import train_test_split

labels = np_utils.to_categorical(y,6)
X = X.astype('float32')
y = y.astype('float32')



# X_train, x_test, Y_train, y_test = train_test_split(X,test_size = 0.3)
# Out:
# Using TensorFlow backend.

# %%
model = Sequential([
    Dense(units=64, input_dim = 561),
    Activation('relu'),
    
    Dense(units = 32),
    Activation('relu'),
    
    Dense(units = 32),
    Activation('relu'),

    Dense(units = 6),
    Activation('softmax'),
])

# %% [markdown]
# model.summary()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 64)                35968
# _________________________________________________________________
# activation_1 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 198
# ...

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.fit(X,labels,epochs=20,validation_split=0.2, batch_size = 25)
# Out:
# Train on 8239 samples, validate on 2060 samples
# Epoch 1/20
# 8239/8239 [==============================] - 1s 166us/step - loss: 0.0630 - acc: 0.9745 - val_loss: 0.1317 - val_acc: 0.9573
# Epoch 2/20
# 8239/8239 [==============================] - 1s 160us/step - loss: 0.0706 - acc: 0.9760 - val_loss: 0.1362 - val_acc: 0.9568
# Epoch 3/20
# 8239/8239 [==============================] - 1s 162us/step - loss: 0.0511 - acc: 0.9801 - val_loss: 0.1540 - val_acc: 0.9563
# Epoch 4/20
# 8239/8239 [==============================] - 1s 168us/step - loss: 0.0519 - acc: 0.9785 - val_loss: 0.1732 - val_acc: 0.9515
# Epoch 5/20
# 8239/8239 [==============================] - 1s 179us/step - loss: 0.0736 - acc: 0.9741 - val_loss: 0.2411 - val_acc: 0.9184
# Epoch 6/20
# 8239/8239 [==============================] - 1s 165us/step - loss: 0.0483 - acc: 0.9817 - val_loss: 0.1623 - val_acc: 0.9505
# Epoch 7/20
# ...
